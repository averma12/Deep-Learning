# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimage
import cv2

# %matplotlib inline

# %%
image = mpimage.imread("noah.jpeg")

# %%
image.shape
# Out:
# (720, 528, 3)

# %%
gray_image = cv2.cvtColor(image,cv2.COLOR_RGB2GRAY)

# %%
plt.imshow(gray_image)

# %%
x = 190
y = 375
gray_image[y,x]
# Out:
# 88

# %%
#Find the maximum and minimum grayscale values in this image

max_val = np.amax(gray_image)
min_val = np.amin(gray_image)

print('Max: ', max_val)
print('Min: ', min_val)
# Out:
# Max:  225
# Min:  0

# %%
# Create a 5x5 image using just grayscale, numerical values
tiny_image = np.array([[0, 20, 30, 150, 120],
                      [200, 200, 250, 70, 3],
                      [50, 180, 85, 40, 90],
                      [240, 100, 50, 255, 10],
                      [30, 0, 75, 190, 220]])

# To show the pixel grid, use matshow
plt.matshow(tiny_image, cmap='gray')

# %%
r = image[:,:,0]
g = image[:,:,1]

# %%
plt.imshow(r)

# %%
g
# Out:
# array([[129, 128, 127, ...,  97, 100, 101],
#        [127, 127, 126, ...,  99, 100, 101],
#        [123, 124, 126, ..., 100, 100, 100],
#        ...,
#        [ 74,  76,  77, ...,  55,  36,  10],
#        [ 75,  77,  78, ...,  60,  51,  35],
#        [ 77,  78,  78, ...,  48,  56,  73]], dtype=uint8)
